# %% [markdown]
# ![](img/logoitqv1.jpg)
#
# ##  01PAO26-26 - Python 1, Data Types
#
# ![](img/python_logo.png)
#
# *Ronald Collaguazo*
#
# **Repositorio:** [Github](https://github.com/Ronald2331/machine.git)
#
# ## 1. Comentarios
#
# ### 1.0.1 ¿Qué son?
#
# Texto contenido en ficheros Python que es ignorado por el intérprete; es decir, no es ejecutado.
#
# ### 1.0.2 ¿Cuál es su utilidad?
#
# - Se puede utilizar para documentar código y hacerlo más legible.
# - Preferiblemente, trataremos de hacer código fácil de entender y que necesite pocos comentarios, en lugar de vernos forzados a recurrir a los comentarios para explicar el código.
#
# ### 1.0.3 Tipos de comentarios
#
# #### Comentarios de una línea
#
# - Texto precedido por #.
# - Se suele usar para documentar expresiones sencillas.
#
# ```python
# # Este es un comentario de una sola línea
# print("Hola Mundo")

# %%
# Esto es una instrucción print
print('Hello world') # Esto es una instrucción print
# Out:
# Hello world

# %% [markdown]
# #### Comentarios de varias líneas
#
# - Texto encapsulado en triples comillas (que pueden ser tanto comillas simples como dobles).
# - Se suele usar para documentar bloques de código más significativos.
#
# python
# """
# Este es un comentario
# de varias líneas
# utilizando comillas dobles.
# """
# print("Hola Mundo")
#
#
# ```python
# '''
# Este es otro comentario
# de varias líneas
# utilizando comillas simples.
# '''
# print("Hola Mundo")

# %%
def producto(x, y):
'''
Esta función recibe dos números como parámetros y devuelve
como resultado el producto de los mismos.
'''
return x * y
# Out:
#   Cell In[2], line 2
#     '''
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# ## 2. Literales, variables y tipos de datos básicos
#
# De forma muy genérica, al ejecutarse un programa Python, simplemente se realizan operaciones sobre objetos.
#
# Estos dos términos son fundamentales:
#
# * *Objetos:* cualquier tipo de datos (números, caracteres o datos más complejos).
# * *Operaciones:* cómo manipulamos estos datos.
#
# Ejemplo:

# %%
4+3
# Out:
# 7

# %% [markdown]
# ## 2.1 Literales
#
# - Python tiene una serie de tipos de datos integrados en el propio lenguaje.
# - Los literales son expresiones que generan objetos de estos tipos.
# - Estos objetos, según su tipo, pueden ser:
#   - Simples o compuestos.
#   - Mutables o immutables.
#
# ### Literales simples
#
# - Enteros
# - Decimales o punto flotante
# - Booleano

# %%
print(4) # número entero
print(4.2) # número en coma flotante
print('Hello world!') # string
print(False)
# Out:
# 4
# 4.2
# Hello world!
# False

# %% [markdown]
# ### Literales compuestos
#
# * Tuplas
# * Listas
# * Diccionarios
# * Conjuntos

# %%
print([1, 2, 3, 3]) # lista - mutable
 print({'Nombre' : 'John Doe', "edad": 30}) # Diccionario - mutable
 print({1, 2, 3, 3}) # Conjunto - mutable
 print((4, 5)) # tupla - inmutable
 2, 4 # tupla
# Out:
#   Cell In[5], line 2
#     print({'Nombre' : 'John Doe', "edad": 30}) # Diccionario - mutable
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## 2.2 Variables
#
# * Referencias a objetos.
# * Las variables y los objetos se almacenan en diferentes zonas de memoria.
# * Las variables siempre referencian a objetos y nunca a otras variables.
# * Objetos sí que pueden referenciar a otros objetos. Ejemplo: listas.
# * Sentencia de asignación:
#
# text
# <nombre_variable> '=' <objeto>

# %%
# # Asignación de variables
# a = 5
# print(a)

# %%
# a = 1 # entero
# b = 4.0 # coma flotante
# c = "ITQ" # string
# d = 10 + 1j # numero complejo
# e = True #False # boolean
# f = None # None
# # visualizar valor de las variables y su tipo
# print(a)
# print(type(a))
# print(b)
# print(type(b))
# print(c)
# print(type(c))
# print(d)
# print(type(d))
# print(e)
# print(type(e))
# print(f)
# print(type(f))

# %% [markdown]
# * Las variables no tienen tipo.
# * Las variables apuntan a objetos que sí lo tienen.
# * Dado que Python es un lenguaje de tipado dinámico, la misma variable puede apuntar, en momentos diferentes de la ejecución del programa, a objetos de diferente tipo.

# %%
# a = 3
# print(a)
# print(type(a))
# a = 'Pablo García'
# print(a)
# print(type(a))
# a = 4.5
# print(a)
# print(type(a))

# %% [markdown]
# * *Garbage collection:* Cuando un objeto deja de estar referenciado, se elimina automáticamente.

# %% [markdown]
# ### Identificadores
#
# * Podemos obtener un identificador único para los objetos referenciados por variables.
# * Este identificador se obtiene a partir de la dirección de memoria.

# %%
a = 3
print(id(a))
a = 'Pablo García'
print(id(a))
a = 4.5
print(id(a))
# Out:
# 140732799362024
# 2175386644880
# 2175385321744

# %% [markdown]
# * *Referencias compartidas:* un mismo objeto puede ser referenciado por más de una variable.
#
#   * Variables que referencian al mismo objeto tienen mismo identificador.

# %%
a = 4567
print(id(a))
# Out:
# 2175385331248

# %%
b = a
print(id(b))
# Out:
# 2175385331248

# %%
c = 4567
print(id(c))
# Out:
# 2175385329488

# %%
a = 25
b = 25
print(id(a))
print(id(b))
print(id(25))
# Out:
# 140732799362728
# 140732799362728
# 140732799362728

# %%
# # Ojo con los enteros "grandes" [-5, 256]
a = 258
b = 258
print(id(a))
print(id(b))
print(id(258))
# Out:
# 2175385329008
# 2175385335696
# 2175385329968

# %% [markdown]
# Referencia al mismo objeto a través de asignar una variable a otra.

# %%
a = 400
b = a
print(id(a))
print(id(b))
# Out:
# 2175385331760
# 2175385331760

# %% [markdown]
# Las variables pueden aparecer en expresiones.

# %%
a = 3
b = 5
print (a + b)
# Out:
# 8

# %%
c = a + b
print(c)
print(id(c))
# Out:
# 8
# 140732799362184

# %% [markdown]
# ### Respecto a los nombres de las variables …
#
# * No se puede poner números delante del nombre de las variables.
# * Por convención, evitar CamelCase. Mejor usar snake_case: uso de "_" para separar palabras.
# * El lenguaje diferencia entre mayúsculas y minúsculas.
# * Deben ser descriptivos.
# * Hay palabras o métodos reservados -> Built-ins y KeyWords
#
#   * Ojo con reasignar un nombre reservado.

# %%
print(pow(3,2))
# Out:
# 9

# %%
print(pow(3,2))
pow = 1 # built-in reasignado
print(pow)
print(pow(3,2))
# Out:
# 9
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 pow = 1 # built-in reasignado
#       3 print(pow)
# ----> 4 print(pow(3,2))
#
# TypeError: 'int' object is not callable

# %%
def pow(a, b):
return a + b

# %% [markdown]
# ### Asignación múltiple de variables

# %%
x, y, z = 1, 2, 3
print(x, y, z)
6
t = x, y, z, 7, "Python"
print(t)
print(type(t))
# Out:
# 1 2 3
# (1, 2, 3, 7, 'Python')
# <class 'tuple'>

# %% [markdown]
# Esta técnica tiene un uso interesante: el intercambio de valores entre dos variables.

# %%
a = 1
b = 2
a, b = b, a
print(a, b)
# Out:
# 2 1

# %%
a = 1
b = 2
c = a
a = b
b = c
print(a, b, c)
# Out:
# 2 1 1

# %% [markdown]
# ## 2.3 Tipos de datos básicos

# %% [markdown]
# ### Bool
#
# - 2 posibles valores: True o False.

# %%
a = False
b = True
print(a)
print(type(a))
print(b)
print(type(b))
# Out:
# False
# <class 'bool'>
# True
# <class 'bool'>

# %% [markdown]
# - True y False también son objetos que se guardan en caché, al igual que los enteros pequeños.

# %%
a = True
b = True
print(id(a))   
print(id(b))    
print(a is b)   
print(a == b)

# %%
print(2)      
print(3.4)    
print(2 + 4j) 
print(1 / 2)
# Out:
# 2
# 3.4
# (2+4j)
# 0.5

# %% [markdown]
# Diferentes representaciones: base 10, 2, 8, 16.

# %%
x = 58          # decimal
z = 0b00111010  # binario
w = 0o72        # octal
y = 0x3A        # hexadecimal
print(x == y == z == w)  # True
# Out:
# True

# %% [markdown]
# *Strings*
#
# - Cadenas de caracteres.
# - Son secuencias: la posición de los caracteres es importante.
# - Son inmutables: las operaciones sobre strings no cambian el string original.

# %%
s = 'John "ee" Doe'
print(s[0])      # J  — Primer carácter
print(s[-1])     # e  — Último carácter
print(s[1:8:2])  # on"e — Slicing
print(s[:])      # John "ee" Doe — Todo el string
print(s + "e")   # John "ee" Doee — Concatenación

# %% [markdown]
# ### 2.4 Conversión entre tipos
#
# - A veces queremos que un objeto sea de un tipo específico.
# - Podemos obtener objetos de un tipo a partir de objetos de un tipo diferente (*casting*).

# %%
a = int(2.8)    # 2
b = int("3")    # 3
c = float(1)    # 1.0
d = float("3")  # 3.0
e = str(2)      # '2'
f = str(3.0)    # '3.0'
g = bool("a")   # True
h = bool("")    # False
i = bool(3)     # True
j = bool(0)     # False
k = bool(None)  # False

print(a); print(type(a))
print(b); print(type(b))
# ... etc.
# Out:
# 2
# <class 'int'>
# 3
# <class 'int'>

# %%
print(7 / 4)      # 1.75 — División convencional. Resultado float
print(7 // 4)     # 1    — División entera. Resultado int
print(int(7 / 4)) # 1    — Conversión de float a int
# Out:
# 1.75
# 1
# 1

# %% [markdown]
# ### 2.5 Operadores
#
# *Operadores aritméticos*
#
# | Operador | Descripción       |
# |----------|-------------------|
# | a + b  | Suma              |
# | a - b  | Resta             |
# | a / b  | División          |
# | a // b | División entera   |
# | a % b  | Módulo / Resto    |
# | a * b  | Multiplicación    |
# | a ** b | Exponenciación    |

# %%
x = 3
y = 2
print('x + y = ', x + y)   # 5
print('x - y = ', x - y)   # 1
print('x * y = ', x * y)   # 6
print('x / y = ', x / y)   # 1.5
print('x // y = ', x // y) # 1
print('x % y = ', x % y)   # 1
print('x * y = ', x * y) # 9
# Out:
# x + y =  5
# x - y =  1
# x * y =  6
# x / y =  1.5
# x // y =  1
# x % y =  1
# x * y =  6

# %% [markdown]
# *Operadores de comparación*
#
# | Operador  | Descripción       |
# |-----------|-------------------|
# | a > b   | Mayor             |
# | a < b   | Menor             |
# | a == b  | Igualdad          |
# | a != b  | Desigualdad       |
# | a >= b  | Mayor o Igual     |
# | a <= b  | Menor o Igual     |

# %%
x = 10
y = 12
print('x > y es ', x > y)   # False
print('x < y es ', x < y)   # True
print('x == y es ', x == y) # False
print('x != y es ', x != y) # True
print('x >= y es ', x >= y) # False
print('x <= y es ', x <= y) # True
# Out:
# x > y es  False
# x < y es  True
# x == y es  False
# x != y es  True
# x >= y es  False
# x <= y es  True

# %% [markdown]
# *Operadores Lógicos*
#
# | Operador  | Descripción                             |
# |-----------|-----------------------------------------|
# | a and b | True, si ambos son True                 |
# | a or b  | True, si alguno de los dos es True      |
# | a ^ b   | XOR — True, si solo uno de los dos es True |
# | not a   | Negación                                |

# %%
x = True
y = False
print('x and y es :', x and y)  # False
print('x or y es :', x or y)    # True
print('x xor y es :', x ^ y)    # True
print('not x es :', not x)      # False
# Out:
# x and y es : False
# x or y es : True
# x xor y es : True
# not x es : False

# %% [markdown]
# *Operadores Bitwise / Binarios*
#
# | Operador  | Descripción                     |
# |-----------|---------------------------------|
# | a & b   | And binario                     |
# | a \| b  | Or binario                      |
# | a ^ b   | Xor binario                     |
# | ~ a     | Not binario                     |
# | a >> b  | Desplazamiento binario derecha  |
# | a << b  | Desplazamiento binario izquierda|

# %%
# x = 0b01100110
# y = 0b00110011
# print("Not x = " + bin(~x))
# print("x and y = " + bin(x & y))
# print("x or y = " + bin(x | y))
# print("x xor y = " + bin(x ^ y))
# print("x << 2 = " + bin(x << 2))
# print("x >> 2 = " + bin(x >> 2))

# %% [markdown]
# *Operadores de Asignación*
#
# | Operador | Descripción                   |
# |----------|-------------------------------|
# | =      | Asignación                    |
# | +=     | Suma y asignación             |
# | -=     | Resta y asignación            |
# | *=     | Multiplicación y asignación   |
# | /=     | División y asignación         |
# | %=     | Módulo y asignación           |
# | //=    | División entera y asignación  |
# | **=    | Exponencial y asignación      |
# | &=     | And y asignación              |
# | \|=    | Or y asignación               |
# | ^=     | Xor y asignación              |
# | >>=    | Despl. Derecha y asignación   |
# | <<=    | Despl. Izquierda y asignación |

# %%
a = 5
a *= 3  # a = a * 3
a += 1  # No existe a++, ni ++a, a--, --a
print(a)  # 16

b = 6
b -= 2  # b = b - 2
print(b)  # 4
# Out:
# 16
# 4

# %% [markdown]
# *Operadores de Identidad*
#
# | Operador     | Descripción                                                      |
# |--------------|------------------------------------------------------------------|
# | a is b     | True, si ambos operandos son referencia al mismo objeto          |
# | a is not b | True, si ambos operandos no son referencia al mismo objeto       |

# %%
a = 4444
b = a
print(a is b)      # True
print(a is not b)  # False
# Out:
# True
# False

# %% [markdown]
# *Operadores de Pertenencia*
#
# | Operador     | Descripción                                |
# |--------------|--------------------------------------------|
# | a in b     | True, si a se encuentra en la secuencia b |
# | a not in b | True, si a no se encuentra en la secuencia b |

# %%
x = 'Hola Mundo'
y = {1: 'a', 2: 'b'}
print('H' in x)      # True
print('hola' not in x)  # True
print(1 in y)        # True
print('a' in y)      # False
# Out:
# True
# True
# True
# False

# %% [markdown]
# 2.6 Entrada de valores

# %%
valor = input("Inserte valor:")
print(valor)
print(type(valor))
# Inserte valor: True
# True
# <class 'str'>
# Out:
# Inserte valor: 5
# 5
# <class 'str'>

# %%
grados_c = int(input("Conversión de grados a fahrenheit, inserte un valor: "))
print(f"Grados F: {1.8 * (grados_c) + 32}")
# Conversión de grados a fahrenheit, inserte un valor: 5
# Grados F: 41.0

# %% [markdown]
# ## 3 Tipos de datos compuestos (colecciones)
#
# ### 3.1 Listas
#
# - Una colección de objetos.
# - *Mutables.*
# - Tipos arbitrarios heterogéneos.
# - Puede contener duplicados.
# - No tienen tamaño fijo.
# - Los elementos van ordenados por posición.
# - Se acceden usando la sintaxis: [index].
# - Los índices van de 0 a n-1.
# - Son un tipo de *Secuencia*, al igual que los strings.
# - Soportan anidamiento.
# - Son una implementación del tipo abstracto de datos: *Array Dinámico*.
#
# *Operaciones con listas*

# %%
# Creación de listas
letras = ['a', 'b', 'c', 'd']
palabras = 'Hola mundo como estas'.split()
numeros = list(range(7))
print(letras)    # ['a', 'b', 'c', 'd']
print(palabras)  # ['Hola', 'mundo', 'como', 'estas']
print(numeros)   # [0, 1, 2, 3, 4, 5, 6]
print(type(numeros))  # <class 'list'>

# %%
# Pueden contener elementos arbitrarios / heterogéneos
mezcla = [1, 3.4, 'a', None, False]
print(mezcla)      # [1, 3.4, 'a', None, False]
print(len(mezcla)) # 5

# %%
# Pueden incluso contener objetos más "complejos"
lista_con_funcion = [1, 2, len, pow]
print(lista_con_funcion)

# %%
# Pueden incluso contener objetos más "complejos"
lista_con_funcion = [1, 2, len, pow]
print(lista_con_funcion)
# Out:
# [1, 2, <built-in function len>, 1]

# %%
# Pueden contener duplicados
lista_con_duplicados = [1, 2, 3, 3, 3, 4]
print(lista_con_duplicados)
# Out:
# [1, 2, 3, 3, 3, 4]

# %%
# Longitud de una lista
letras = ['a', 'b', 'c', 'd', 1]
print(len(letras))  # 5
# Out:
# 5

# %%
# Acceso a un elemento
print(letras[2])   # c
print(letras[-5])  # a
print(letras[0])   # a
# Out:
# c
# a
# a

# %%
# Slicing: lista[inicio:fin:paso]
letras = ['a', 'b', 'c', 'd', 'e']
print(letras[1:3])   # ['b', 'c']
print(letras[:3])    # ['a', 'b', 'c']
print(letras[:-1])   # ['a', 'b', 'c', 'd']
print(letras[2:])    # ['c', 'd', 'e']
print(letras[:])     # ['a', 'b', 'c', 'd', 'e']
print(letras[::2])   # ['a', 'c', 'e']
# Out:
# ['b', 'c']
# ['a', 'b', 'c']
# ['a', 'b', 'c', 'd']
# ['c', 'd', 'e']
# ['a', 'b', 'c', 'd', 'e']
# ['a', 'c', 'e']

# %%
# Copiar una lista con slicing
letras = ['a', 'b', 'c', 'd']
a = letras[:]
print(a)              # ['a', 'b', 'c', 'd']
print(letras.copy())  # ['a', 'b', 'c', 'd']
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'b', 'c', 'd']

# %%
# Añadir un elemento al final
letras.append('e')
print(letras)

# También con +=
letras += 'e'
print(letras)
# Out:
# ['a', 'b', 'c', 'd', 'e']
# ['a', 'b', 'c', 'd', 'e', 'e']

# %%
# Insertar en posición
letras.insert(1, 'g')
print(letras)
# Out:
# ['a', 'g', 'b', 'c', 'd', 'e', 'e']

# %%
# Modificación individual
letras[5] = 'f'
print(letras)

# Modificación múltiple con slicing
letras = ['a', 'b', 'c', 'f', 'g', 'h', 'i', 'j', 'k']
letras[0:7:2] = ['z', 'x', 'y', 'p']
print(letras)  # ['z', 'b', 'x', 'f', 'y', 'h', 'p', 'j', 'k']
# Out:
# ['a', 'g', 'b', 'c', 'd', 'f', 'e']
# ['z', 'b', 'x', 'f', 'y', 'h', 'p', 'j', 'k']

# %%
# Anidamiento con asignación individual
numeros = [1, 2, 3]
numeros[1] = [10, 20, 30]
print(numeros)          # [1, [10, 20, 30], 3]
print(numeros[1][0])    # 10
numeros[1][2] = [100, 200]
print(numeros)          # [1, [10, 20, [100, 200]], 3]
print(numeros[1][2][1]) # 200
# Out:
# [1, [10, 20, 30], 3]
# 10
# [1, [10, 20, [100, 200]], 3]
# 200

# %%
# Eliminar un elemento
if 'p' in letras:
    letras.remove('p')
print(letras)

# pop() — elimina el último elemento y lo devuelve
elemento = letras.pop()
print(elemento)
print(letras)
# Out:
# ['z', 'b', 'x', 'f', 'y', 'h', 'j', 'k']
# k
# ['z', 'b', 'x', 'f', 'y', 'h', 'j']

# %%
# Encontrar índice de un elemento
letras = ['a', 'b', 'c', 'c']
if 'a' in letras:
    print(letras.index('a'))  # 0
# Out:
# 0

# %%
# Concatenar listas
lacteos = ['queso', 'leche']
frutas = ['naranja', 'manzana']
compra = lacteos + frutas
print(compra)  # ['queso', 'leche', 'naranja', 'manzana']

# Sin crear nueva lista
frutas.extend(['pera', 'uvas'])
print(frutas)  # ['naranja', 'manzana', 'pera', 'uvas']

# Anidar sin crear nueva lista
frutas.append(['pera', 'uvas'])
print(frutas)  # ['naranja', 'manzana', ['pera', 'uvas']]
# Out:
# ['queso', 'leche', 'naranja', 'manzana']
# ['naranja', 'manzana', 'pera', 'uvas']
# ['naranja', 'manzana', 'pera', 'uvas', ['pera', 'uvas']]

# %%
# Replicar una lista
lacteos = ['queso', 'leche']
print(lacteos * 3)
# ['queso', 'leche', 'queso', 'leche', 'queso', 'leche']
# Out:
# ['queso', 'leche', 'queso', 'leche', 'queso', 'leche']

# %%
# Ordenar una lista
lista = [4, 3, 8, 1]
lista.sort()
print(lista)               # [1, 3, 4, 8]
lista.sort(reverse=True)
print(lista)               # [8, 4, 3, 1]

# sorted() no modifica la lista original
compra = ['Huevos', 'Pan', 'zapallo', 'Leche', 'Licor']
print(sorted(compra))  # ['Huevos', 'Leche', 'Licor', 'Pan', 'zapallo']
print(compra)          # ['Huevos', 'Pan', 'zapallo', 'Leche', 'Licor']
# Out:
# [1, 3, 4, 8]
# [8, 4, 3, 1]
# ['Huevos', 'Leche', 'Licor', 'Pan', 'zapallo']
# ['Huevos', 'Pan', 'zapallo', 'Leche', 'Licor']

# %%
# Pertenencia
lista = [1, 2, 3, 4]
print(1 in lista)  # True
print(5 in lista)  # False
# Out:
# True
# False

# %%
# Anidamiento
letras = ['a', 'b', 'c', ['x', 'y', ['i', 'j', 'k']]]
print(letras[0])       # a
print(letras[3][0])    # x
print(letras[3][2][0]) # i# Anidamiento
letras = ['a', 'b', 'c', ['x', 'y', ['i', 'j', 'k']]]
print(letras[0])       # a
print(letras[3][0])    # x
print(letras[3][2][0]) # i
# Out:
# a
# x
# i
# a
# x
# i

# %% [markdown]
# *Alias / Referencias en las listas*

# %%
lista = [2, 4, 16, 32]
ref = lista
ref[2] = 64
print(ref)    # [2, 4, 64, 32]
print(lista)  # [2, 4, 64, 32]  ← también cambia!
# Out:
# [2, 4, 64, 32]
# [2, 4, 64, 32]

# %%
# Copia superficial
lista = [2000, 4, 16, 32]
copia = lista[:]   # o lista.copy()
copia[2] = 64
print(lista)  # [2000, 4, 16, 32]
print(copia)  # [2000, 4, 64, 32]
# Out:
# [2000, 4, 16, 32]
# [2000, 4, 64, 32]

# %%
# Las listas anidadas se copian por referencia
lista = [2, 4, 16, 32, [34, 10, [5, 5]]]
copia = lista.copy()
copia[3] = 20
copia[4][0] = 28
print(copia)  # [2, 4, 16, 20, [28, 10, [5, 5]]]
print(lista)  # [2, 4, 16, 32, [28, 10, [5, 5]]]  ← sublista afectada!
# Out:
# [2, 4, 16, 20, [28, 10, [5, 5]]]
# [2, 4, 16, 32, [28, 10, [5, 5]]]

# %%
# Evitar que listas anidadas se copien por referencia → deepcopy
import copy
lista = [2, 4, 16, 32, [34, 10, [5, 5]]]
copia = copy.deepcopy(lista)
copia[0] = 454
copia[4][2][0] = 64
print(lista)
print(copia)
# Out:
# [2, 4, 16, 32, [34, 10, [5, 5]]]
# [454, 4, 16, 32, [34, 10, [64, 5]]]

# %% [markdown]
# ### 3.2 Diccionarios
#
# - Colección de parejas *clave-valor*.
# - *Mutables.*
# - *Claves:* cualquier objeto inmutable; sólo pueden aparecer una vez.
# - *Valores:* sin restricciones.
# - Desde la versión 3.7 están *ordenados*.
# - Se pueden ver como listas indexadas por cualquier objeto inmutable.
# - A diferencia de las listas, no son secuencias. Son *mappings*.

# %%
# Creación simple
persona = {'DNI': '11111111D', 'Nombre': 'Carlos', 'Edad': 34}
print(persona)

# Creación uniendo dos colecciones
nombres = ['Pablo', 'Manolo', 'Pepe', 'Juan']
edades = [52, 14, 65]
datos = dict(zip(nombres, edades))
print(datos)  # {'Pablo': 52, 'Manolo': 14, 'Pepe': 65}

# Creación con dict()
persona2 = dict(nombre='Rosa', apellido='Garcia')
print(persona2)

# Creación desde lista de tuplas
persona2 = dict([('nombre', 'Rosa'), ('apellido', 'Garcia')])
print(persona2)

# Creación incremental
persona = {}
persona['DNI'] = '11111111D'
persona['Nombre'] = 'Carlos'
persona['Edad'] = 34
print(persona)
# Out:
# {'DNI': '11111111D', 'Nombre': 'Carlos', 'Edad': 34}
# {'Pablo': 52, 'Manolo': 14, 'Pepe': 65}
# {'nombre': 'Rosa', 'apellido': 'Garcia'}
# {'nombre': 'Rosa', 'apellido': 'Garcia'}
# {'DNI': '11111111D', 'Nombre': 'Carlos', 'Edad': 34}

# %%
# Acceso a un valor
persona = {'DNI': '11111111D', 'Nombre': 'Carlos', 'Edad': 34}
print(persona['Nombre'])  # Carlos

# Acceso seguro con get()
# persona.get('Trabajo', "En el paro")
# Out:
# Carlos

# %%
 #Modificación de un valor
 persona['Nombre'] = 'Fernando'
 persona['Edad'] += 1

 #Añadir un valor
 persona['Ciudad'] = 'Valencia'

 #Eliminar un valor
 del persona['Ciudad']
 value = persona.pop('Edad')

 #Comprobar existencia
 print('Nombre' in persona)
 print('Apellido' in persona)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #Modificación de un valor
# ----> 2 persona['Nombre'] = 'Fernando'
#       3 persona['Edad'] += 1
#       5 #Añadir un valor
#
# NameError: name 'persona' is not defined

# %%
# Anidamiento
# persona = {
#     'Trabajos': ['desarrollador', 'gestor'],
#     'Direccion': {'Calle': 'Pintor Sorolla', 'Ciudad': 'Valencia'}
# }
# print(persona['Direccion']['Ciudad'])

# %%
# Métodos items, keys, values
# persona = {'DNI': '11111111D', 'Nombre': 'Carlos', 'Edad': 34}
# print(list(persona.items()))
# print(list(persona.keys()))
# print(list(persona.values()))

# Iterar
# for key in dict_simple.keys():
#     print(key)
# for key, value in dict_simple.items():
#     print('Clave: ' + str(key) + ', valor: ' + str(value))

# %% [markdown]
# ### 3.3 Sets (Conjuntos)
#
# Al igual que las listas:
#
# - Colección de elementos, tipos arbitrarios.
# - *Mutables.*
# - No tienen tamaño fijo.
#
# A diferencia de las listas:
#
# - *No puede tener duplicados.*
# - Se definen por medio de llaves {}.
# - Los elementos *no van ordenados* por posición.
# - Solo pueden contener *objetos inmutables*.
# - *No soportan anidamiento.*
#
# *Operaciones con conjuntos*

# %%
# Creación
# set1 = {0, 1, 1, 2, 3, 4, 4}
# set2 = {'user1', 12, 2}
# set3 = set(range(7))
# set4 = set([0, 1, 2, 3, 4, 0, 1])

# Diferencia entre lista y conjunto
# s = 'aabbc'
# print(list(s))  # ['a', 'a', 'b', 'b', 'c']
# print(set(s))   # {'a', 'b', 'c'}

# %%
# Unión, intersección, diferencia
# set1 = {0, 1, 1, 2, 3, 4, 5, 8, 13, 21}
# set2 = set([0, 1, 2, 3, 4, 42])
# print(set1 | set2)   # unión
# print(set1 & set2)   # intersección
# print(set1 - set2)   # diferencia

# Con métodos (admiten cualquier iterable)
# conjunto = {0, 1, 2}
# lista = [1, 3, 3]
# print(conjunto.union(lista))
# print(conjunto.intersection(lista))
# print(conjunto.difference(lista))

# %%
# Comparación de conjuntos
# print(set2.issubset(set1))
# print(set1.issuperset(set2))
# print(set1.isdisjoint(set2))

# %%
# Modificación
# set1 |= set2    # unión y asignación
# set1 &= set2    # intersección y asignación
# set1 -= set2    # diferencia y asignación

# Con métodos
# set1.update(set2)
# set1.intersection_update(set2)
# set1.difference_update(set2)

# add y remove
# set1.add('d')
# set1.remove('a')

# %% [markdown]
# ### 3.4 Tuplas
#
# Al igual que las listas:
#
# - Colección de elementos, tipos arbitrarios.
# - Puede contener duplicados.
# - No tienen tamaño fijo.
# - Los elementos van ordenados por posición; acceso con [index].
# - Soportan anidamiento.
#
# A diferencia de las listas:
#
# - Se definen por medio de *paréntesis*.
# - *Inmutables.*
#
# ¿Por qué tuplas?
#
# - Representación de una colección fija de elementos (por ejemplo, una fecha).
# - Pueden usarse como claves de un diccionario.
#
# *Operaciones con tuplas*

# %%
# Creación
# tuple1 = ('Foo', 34, 5.0, 34)
# tuple2 = 1, 2, 3
# tuple3 = tuple(range(10))
# tuple4 = tuple([0, 1, 2, 3, 4])

# Ojo: los paréntesis solos no crean una tupla
# singleton_number = (1)    # int
# singleton_tuple = (1,)    # tuple

# %%
# Acceso por índice
# tuple1 = ('Foo', 1, 2, 3)
# print(tuple1[0])              # Primer elemento
# print(tuple1[-1])             # Último elemento
# print(tuple1[-len(tuple1)])   # Primer elemento

# Las tuplas son inmutables → asignación falla
# tuple1[0] = 'bar'  # TypeError

# %%
# Modificar una tupla (vía conversión)
# lista = list(tuple1)
# lista[0] = 'bar'
# tuple1 = tuple(lista)

# %%
# Contar ocurrencias
# tuple1 = ('Foo', 34, 5.0, 34)
# print(tuple1.count(34))  # 2

# Encontrar índice
# indice = tuple1.index(34)
# print(tuple1[indice])

# %%
# Desempaquetar una tupla
# tuple1 = (1, 2, 3, 4)
# a, b, c, d = tuple1
# a, b, *resto = tuple1
# print(resto)  # [3, 4]

# %% [markdown]
# ### 3.5 Secuencias
#
# - Formalmente, objetos iterables no materializados.
# - No son listas; usar list() para materializarlas.
# - Ejemplos: range, enumerate.

# %%
# range
list(range(0, 10, 2))  # [0, 2, 4, 6, 8]

# enumerate
lista = [10, 20, 30]
print(list(enumerate(lista)))  # [(0, 10), (1, 20), (2, 30)]

for index, value in enumerate(lista):
    print('Index = ' + str(index) + '. Value = ' + str(value))
# Out:
# [(0, 10), (1, 20), (2, 30)]
# Index = 0. Value = 10
# Index = 1. Value = 20
# Index = 2. Value = 30

# %%
# zip — une elemento a elemento dos colecciones
nombres = ['Manolo', 'Pepe', 'Luis']
edades = [31, 34, 34]
for nombre, edad in zip(nombres, edades):
    print('Nombre: ' + nombre + ', edad: ' + str(edad))

# unzip
jugadores = zip(nombres, edades)
ns, es = zip(*jugadores)
print(list(ns))
# Out:
# Nombre: Manolo, edad: 31
# Nombre: Pepe, edad: 34
# Nombre: Luis, edad: 34
# ['Manolo', 'Pepe', 'Luis']

# %% [markdown]
# ### 3.6 En Python todo son objetos
#
# Cada objeto tiene:
#
# - *Identidad:* nunca cambia una vez creado. Operador is compara identidad. Función id() devuelve identidad.
# - *Tipo:* determina posibles valores y operaciones. Función type() devuelve el tipo. No cambia.
# - *Valor:* pueden ser mutables o inmutables.
#   - *Tipos mutables:* list, dictionary, set y tipos definidos por el usuario.
#   - *Tipos inmutables:* int, float, bool, string y tuple.

# %%
# Asignación
list_numbers = [1, 2, 3]    # Lista (mutable)
tuple_numbers = (1, 2, 3)   # Tupla (inmutable)
list_numbers[0] = 100       # OK
# tuple_numbers[0] = 100    # TypeError

# Identidad
list_numbers += [4, 5, 6]   # La lista original se extiende → mismo id
tuple_numbers += (4, 5, 6)  # Se crea un nuevo objeto → id diferente

# Referencias
list_numbers_2 = list_numbers  # referencia compartida
list_numbers.append(4)
print(list_numbers)    # [1, 2, 3, 4]
print(list_numbers_2)  # [1, 2, 3, 4]  ← también cambia

# Inmutables
text = "Hola"
text_2 = text
text += " Mundo"
print(text)    # Hola Mundo
print(text_2)  # Hola  ← no cambia (nuevo objeto)
# Out:
# [100, 2, 3, 4, 5, 6, 4]
# [100, 2, 3, 4, 5, 6, 4]
# Hola Mundo
# Hola

# %%
# Curiosidad: tupla inmutable con lista mutable dentro
teams = ["Team A", "Team B", "Team C"]
player = (23, teams)
teams[2] = "Team J"
print(player)  # (23, ['Team A', 'Team B', 'Team J']) ← la lista sí cambia
# player[1][0] = 'Team XX'  → esto también funciona (modifica la lista)
# Out:
# (23, ['Team A', 'Team B', 'Team J'])

# %% [markdown]
# ## 4 Ejercicios
#
# 1. Escribe un programa que muestre la concatenación de un número y una cadena de caracteres. Dado el número 3 y la cadena 'abc', mostrar '3abc'.
# 2. Escribe un programa que indique si un entero N está contenido en un intervalo semiabierto [a, b).
# 3. Dado dos strings S1, S2 y dos enteros N1, N2, determinar si el substring de S1 desde N1 a N2 (ambos inclusive) está contenido en S2.
# 4. Dada una lista con elementos duplicados, mostrar una nueva lista sin duplicados.
# 5. Dada una lista de strings L, un string s perteneciente a L y un string t, reemplazar s por t en L.
# 6. Definir una tupla con elementos numéricos, reemplazar el último valor y mostrarla. (Las tuplas son inmutables; usa objetos intermedios.)
# 7. Dada [1,2,3,4,5,6,7,8], obtener [8,6,4,2].
# 8. Dada una tupla y un índice válido i, eliminar el elemento en posición i usando solo tuplas.
# 9. Obtener la mediana de una lista de números.
#
#
# ## 5 Soluciones

# %%
 # Ejercicio 1
x = 3
y = 'abc'
print(str(x) + y)
# Out:
# 3abc

# %%
# Ejercicio 2
N = 5
a = 0
b = 6
# print(a<=N)
# print(N<b)
print(a <= N and N < b)
# Out:
# True

# %%
# Ejercicio 3
S1 = 'Java'
S2 = 'JavaScript'
N1 = 0
N2 = 3
print(S1[N1:N2+1] in S2)
# Out:
# True

# %%
# Ejercicio 4
L = [1,2,2,3,3,2,3,1,4,5,4,5,5]
print(list(set(L)))
# Out:
# [1, 2, 3, 4, 5]

# %%
# Ejercicio 5
#Escribe un programa que, dada una lista de strings L, un string s perteneciente a L y un string t,
#reemplace s por t en L. El programa debe mostrar la lista resultante por pantalla.
L = ["Python", "Java", "C++", "Kotlin"]
s = "Java"
t = "JavaScript"
indice = L.index(s)
L[indice] = t
print(L)
# Out:
# ['Python', 'JavaScript', 'C++', 'Kotlin']

# %%
# Ejercicio 6
#Escribe un programa que defina una tupla con elementos numéricos, reemplace el valor del último por un valor diferente y muestre
#la tupla por pantalla. Recuerda que las tuplas son inmutables. Tendrás que usar objetos intermedios.
tupla = (1,2,3,4)
lista = list(tupla)
lista[-1] = 5
print(tuple(lista))
# Out:
# (1, 2, 3, 5)

# %%
# Ejercicio 7
#Dada la lista [1,2,3,4,5,6,7,8] escribe un programa que, a partir de esta lista,
#obtenga la lista [8,6,4,2] y la muestre por pantalla.
lista = [1,2,3,4,5,6,7,8]
print(lista[-1::-2]) #(inicio, fin, paso)
# Out:
# [8, 6, 4, 2]

# %%
# Ejercicio 8
#Escribe un programa que, dada una tupla y un índice válido i, elimine el elemento de la tupla que se encuentra en la posición i.
#Para este ejercicio sólo puedes usar objetos de tipo tupla. No puedes convetir la tupla a una lista, por ejemplo.
38
tupla = ('a', 'b', 'c', 'd', 'e', 'f')
i = 3
print(tupla[:i] + tupla[i+1:])
# Out:
# ('a', 'b', 'c', 'e', 'f')

# %%
 # Ejercicio 9
#Escribe un programa que obtenga la mediana de una lista de números. Recuerda que la mediana M de una lista de números L
#es el número que cumple la siguiente propiedad: la mitad de los números de L son superiores a M y la otra mitad son inferiores.
#Cuando el número de elementos de L es
#par, se puede considerar que hay dos medianas. No obstante, en este ejercicio consideraremos que únicamente existe una mediana.
L = [21, 9, 1, 5.5, 19, 3, 15]
L.sort()
print(L)
mediana = L[len(L)//2]
print(mediana)
# Out:
# [1, 3, 5.5, 9, 15, 19, 21]
# 9
